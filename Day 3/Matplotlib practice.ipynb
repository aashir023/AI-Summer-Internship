# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = r'C:\Users\Aashir\Downloads\data.csv'
df = pd.read_csv(file_path)
df.plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

filepath= r'C:\Users\Aashir\Downloads\data.csv'
df = pd.read_csv(filepath)
df['Duration'].plot(kind ='hist')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2 , 8])

y = np.array([4 , 10])

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 20, 15])

plt.plot(ypoints, marker = 'o', ms = 15, mfc = 'r', ls = '--', color = 'grey', lw =3)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.array([3, 8])
y = np.array([6, 2])

plt.plot(x,y, marker = 'o', ms = 5)

plt.title("Workout data")
title.loc[]
plt.xlabel("Time")
plt.ylabel("Distance")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data" , loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports watch data")
plt.xlabel("Distance")
plt.ylabel("Time")

plt.plot(x,y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch data", loc = 'left')
plt.xlabel("Distance")
plt.ylabel("Time")

plt.grid( color = 'r', ls = '--', lw = 3)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,1,1)
plt.title("INCOME")
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2,1,2)
plt.title("SALES")
plt.plot(x,y)

plt.suptitle("My shop")

plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.xlabel("HOW OLD THE CAR IS")
plt.ylabel("sSPEED OF THE CAR")


plt.scatter(x,y, color =colors )


plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

#1st plot 
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y, color = 'green')

#2nd plot 
#day two, the age and speed of 13 cars:

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

plt.scatter(x, y)

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))

colors = np.random.randint(100, size = (100))
size = 10 * np.random.randint(100, size =(100))

plt.scatter(x,y , c = colors, s =size, alpha = 0.5, cmap = 'nipy_spectral')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['A','B', 'C', 'D'])
plt.xlabel("GRADES")
plt.ylabel("MARKS")
y = np.array([83, 70, 50, 40])

plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Apple", "Banana", "mango", "pinapple"])
y = np.array([300, 400, 250, 700])

plt.bar(x,y, color = 'red', width = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

num = np.random.normal(170, 10, 250)

plt.hist(num)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
expl = [0.2, 0,0,0]

colors = ["black", "violet", "indigo", "brown"]

plt.pie(y, labels = mylabels, startangle = 90, colors = colors, shadow = True)

plt.legend(title = "Four fruits")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# C:\Users\Aashir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0,1,2,3,4,5], hist = False)

plt.show()
# Out:
# C:\Users\Aashir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn import datasets

iris = datasets.load_iris()
print(iris.data.shape)
# Out:
# (150, 4)

# %%
from sklearn import datasets

iris = datasets.load_iris()
print(iris.data.shape)
# Out:
# (150, 4)

# %%
from sklearn import datasets

iris = datasets.load_iris()
print(iris.data.shape)
# Out:
# (150, 4)

# %%
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
Y = iris.target

feature_names = iris.feature_names
target_names = iris.target_names

print("Feature names  : ", feature_names)
print("Target names : ", target_names)

print("\nType of X ", type(X))

print("First 5 rows : ", X[:5])
# Out:
# Feature names  :  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names :  ['setosa' 'versicolor' 'virginica']
#
# Type of X  <class 'numpy.ndarray'>
# First 5 rows :  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
Y = iris.target

feature_names = iris.feature_names
target_names = iris.target_names

print("The type of data : \n", type(X))
print(feature_names)
print(target_names)

print("\nfirst five rows : \n", X[:5])
# Out:
# The type of data :
#  <class 'numpy.ndarray'>
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
#
# first five rows :
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
import pandas as pd
import numpy as np

file_path = r'C:\Users\Aashir\Desktop\movies.csv'
data = pd.read_csv(file_path)

print("Shape ", data.shape)
print("\nfeatures ",data.columns)
    
X = data[data.columns[:-1]]
Y = data[data.columns[-1]]

print("Feature Matrix :\n", X.head(2))
print("Response Vector :\n", Y.head(2))
# Out:
# Shape  (1000, 9)
#
# features  Index(['Unnamed: 0', 'SN', 'Movie', 'Worldwide', 'India Net', 'India Gross',
#        'Overseas', 'Budget', 'Verdict'],
#       dtype='object')
# Feature Matrix :
#     Unnamed: 0  SN                       Movie    Worldwide   India Net  \
# 0           0   1                     Pathaan  10500000000  5240000000
# 1           1   2  Baahubali 2 The Conclusion  17880000000  5100000000
#
#    India Gross    Overseas      Budget
# 0   6570000000  3920000000  2500000000
# 1  14160000000  3710000000  2500000000
# Response Vector :
#  0    All Time Blockbuster
# 1    All Time Blockbuster
# Name: Verdict, dtype: object

# %%
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
Y = iris.target

from sklearn.model_selection import train_test_split
x_train, x_test, y_train
